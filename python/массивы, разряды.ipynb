# %%
a = input("Введите ваше имя")
b = input("Введите ваше отчество")
c = input("Введите вашу фамилию")

print(c + " " + a + " " + b)
# Out:
# Введите ваше имя Маргарита
# Введите ваше отчество Юрьевна
# Введите вашу фамилию Крипак
# Крипак Маргарита Юрьевна

# %%
a = input("Введите ваше имя")
b = input("Введите ваше отчество")
c = input("Введите вашу фамилию")

print(c + " " + a[0] + "." + b[0] + ".")
# Out:
# Введите ваше имя Маргарита
# Введите ваше отчество Юрьевна
# Введите вашу фамилию Крипак
# Крипак М.Ю.

# %%
a = input("Введите ваше имя")
b = input("Введите ваше отчество")
c = input("Введите вашу фамилию")

print(c, a, b)
# Out:
# Введите ваше имя Маргарита
# Введите ваше отчество Юрьевна
# Введите вашу фамилию Крипак
# Крипак Маргарита Юрьевна

# %%
a = input("Введите ваше имя")
b = input("Введите ваше отчество")
c = input("Введите вашу фамилию")

print(c," ", a[0], "." , b[0], ".", sep = "")
# Out:
# Введите ваше имя Маргарита
# Введите ваше отчество Юрьевна
# Введите вашу фамилию Крипак
# Крипак М.Ю.

# %%
number = int( input ( "введите число"))
5478
print("позиция - тыс.", number/1000)
print("позиция - сот.")
print("позиция - дес.")
print("позиция - ед.")
# Out:
# введите число 1234
# позиция - тыс. 1.234
# позиция - сот.
# позиция - дес.
# позиция - ед.

# %%
number = int( input ( "введите число"))
5478
print("позиция - тыс.", number//1000)
print("позиция - сот.", number % 1000 // 100)
print("позиция - дес.", number % 100 // 10)
print("позиция - ед.", number % 10)
# Out:
# введите число 1234
# позиция - тыс. 1
# позиция - сот. 2
# позиция - дес. 3
# позиция - ед. 4

# %%
number = input ( "введите число")
5478
print("позиция - тыс.", number[0])
print("позиция - сот.", number[1])
print("позиция - дес.", number[2])
print("позиция - ед.", number [3])
# Out:
# введите число 3456
# позиция - тыс. 3
# позиция - сот. 4
# позиция - дес. 5
# позиция - ед. 6

# %%
number = int( input( "введите рост в см"))

print( number, "- это", number//100, "м", number%100, "см")
# Out:
# введите рост в см 173
# 173 - это 1 м 73 см

# %%
number = input( "введите рост в см")

print( number, "- это", number[0], "м", number[1] + number[2], "см")
# Out:
# введите рост в см 173
# 173 - это 1 м 73 см

# %%
a = int( input( "введите время в минутах"))
# 144 2ч 24м
print( a, "- это", a//60, "ч", a%60, "м")
# Out:
# введите время в минутах 144
# 144 - это 2 ч 24 м

# %%
#                        -6    -1
text = "Я программирую на Python"
#       012345                26

print("Первый символ - ", text[0])
print("Первый символ - ", text[0:10])
print("Первый символ - ", text[0:-6])
print("Середина - ", text[2:14])
print("Середина - ", text[2:17])
print("Середина - ", text[15:17])
print("Середина - ", text[18:26])

print("Середина - ", text[-6:26])
# Out:
# Первый символ -  Я
# Первый символ -  Я программ
# Первый символ -  Я программирую на
# Середина -  программирую
# Середина -  программирую на
# Середина -  на
# Середина -  Python
# Середина -  Python

# %%
fio = "Иванов Андрей Иванович"
print( fio[0:6] + " " + fio[7] + "." + fio[14])
# Out:
# Иванов А.И

# %%
rub = input("коп") # xxx
print ( rub[0] , "руб.", rub[1:3] , "коп.")
# Out:
# коп 345
# 3 руб. 45 коп.

# %%
number = input( "введите рост в см")

print( number, "- это", number[0:-2], "м", number[-2:], "см")
# Out:
# введите рост в см 2345
# 2345 - это 23 м 45 см

# %%
rub = input("коп") # xxx
print ( rub[0:-2] , "руб.", rub[-2:] , "коп.")
# Out:
# коп 1324
# 13 руб. 24 коп.
