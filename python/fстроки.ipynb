# %%
text = "Привет мир!"
print( f "{text:^80}" )
# Out:
#                                   Привет мир!

# %%
a = 86
b = 12300
print( a * b )
# Out:
# 1057800

# %%
a = 86
b = 12300
print(f " {a * b:,} " )
# Out:
#  1,057,800

# %%
a = 86.27
b = 12303
print(f"{a * b:,}" )
# Out:
# 1,061,379.81

# %%
a = 86.2768
b = 12303
print(f"{a * b:,.10f}" )
# Out:
# 1,061,463.4704000000

# %%
a = 86.2768
b = 12303
print(f"{a * b:,.2f}" )
# Out:
# 1,061,463.47

# %%
a = 8.6
print (f"Погода в Москве {a:^30.0f}")
# Out:
# Погода в Москве               9

# %%
a = 101
print( f"{ a:06}")
# Out:
# 000101

# %%
a = 1286.27
print( f"{a:,.2f}")
print( f"${a:,.2f}")
print( f"{a:,.2f}$")
# Out:
# 1,286.27
# $1,286.27
# 1,286.27$
