# %%
name = " Маргарита "
print( " Доброе утро, " , name )
# Out:
#  Доброе утро,   Маргарита

# %%
name = " Маргарита "
print( name )
# Out:
#  Маргарита

# %%
name = " Маргарита "
print( "Привет, " , name )
# Out:
# Привет,   Маргарита

# %%
name = "Маргарита"
surname = 'Крипак'
print( "Доброе утро, " , name, surname, '!' )
# Out:
# Доброе утро,  Маргарита Крипак !

# %%
a = 10
b = 2
c = a + b
print ( c )
# Out:
# 12

# %%
a = 10
b = 2
print ( a + b )
# Out:
# 12

# %%
name = input()
print( " Доброе утро, " , name )
# Out:
#  Маргарита
#  Доброе утро,  Маргарита

# %%
name = input("Введите ваше имя")
surname = input("Введите вашу фамилию")
print( "Доброе утро, " , name, surname, '!' )
# Out:
# Введите ваше имя Маргарита
# Введите вашу фамилию Крипак
# Доброе утро,  Маргарита Крипак !

# %%
name = "Рита"
name = "Даша"
name = "Света"
print(name)
# Out:
# Света

# %%
a, b, c = 10, 2, 5
print(a + b + c)
# Out:
# 17

# %%
a, b, c = 10, 10, 10
print(a + b + c)
# Out:
# 30

# %%
a, b, c = 20, a, a 
print(a + b + c)
# Out:
# 60

# %%
a = 20
b = 20
c = 20
print(a + b + c)
# Out:
# 60

# %%
srt = "Я программирую на Python"
print( srt )
# Out:
# Я программирую на Python

# %%
print("Я" , "программирую", "на", "Python" )
# Out:
# Я программирую на Python

# %%
word1 = "Я"
word2 = "программирую"
word3 = "на"
word4 = "Python"
print( word1, word2, word3, word4 )
# Out:
# Я программирую на Python

# %%
word1 = "Я"
word2 = "программирую"
word3 = "на"
word4 = "Python"
MegaWord = word1 + word2 + word3 + word4
print( MegaWord )
# Out:
# ЯпрограммируюнаPython

# %%
word1 = "Я"
word2 = "программирую"
word3 = "на"
word4 = "Python"
print( word1, word2, word3, word4, sep = "---" )
# Out:
# Я---программирую---на---Python

# %%
word1 = "Я"
word2 = "программирую"
word3 = "на"
word4 = "Python"
print( word1, word2, word3, word4, sep = "  " )
# Out:
# Я  программирую  на  Python

# %%
word1 = "Я"
word2 = "программирую"
word3 = "на"
word4 = "Python"
print( word1, word2, word3, word4, sep = "*"*5 )
# Out:
# Я*****программирую*****на*****Python
